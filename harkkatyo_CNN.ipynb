# %% [markdown]
# # Syväoppimisen harjoitustyö
# Työn aiheena pistiäiskuvien luokittelu ja datan lähteenä https://www.kaggle.com/datasets/thedatasith/hymenoptera
# Tarkoitus on siis erottaa Hymenoptera-lahkon hyönteisten kuvamateriaalista muurahaiset erilleen mesipistiäisistä. Taksonomisesti sekä muurahaiset että mesipistiäiset kuuluvat hoikkatyvisiin pistiäisiin, eli ovat varsin läheistä sukua toisilleen. Haastetta varmaankin riittää. Inspiraatiota aiheen valintaan tarjosi hyönteisharrastus ja kurssin päättymisviikonlopun BioBlitz Turku. Katsotaan mitä tästä tulee.

# %%
#tarvittavat kirjastot kootusti tähän
import tensorflow as tf
import glob
import random
import ipyplot # !pip install ipyplot
import matplotlib.pyplot as plt

# %%
#datan lataaminen ja esikäsittely. Data on ladattu paikalliseen hakemistoon.

train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    'data/Hymenoptera/train', labels='inferred', label_mode='int', class_names=None,
    color_mode='rgb', batch_size=32, image_size=(224, 224), shuffle=True,
    validation_split=None, subset=None, interpolation='bilinear'
)
test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    'data/Hymenoptera/val', labels='inferred', label_mode='int', class_names=None,
    color_mode='rgb', batch_size=32, image_size=(224, 224), shuffle=True,
    validation_split=None, subset=None, interpolation='bilinear'
)
train_dataset
# Out:
# Found 242 files belonging to 2 classes.
# Found 153 files belonging to 2 classes.
# <BatchDataset shapes: ((None, 224, 224, 3), (None,)), types: (tf.float32, tf.int32)>

# %% [markdown]
# # oma kommentti
# Kun aloin selvitellä, kuinka ulkoisen jpg-kuvan saa syötteeksi, löytyi tämmöinen kätevä työkalu. Tässä käytetty `image_dataset_from_directory()` osaa jakaa kuvat suoraan luokkiin, kunhan polun takana aukeaa oikeanlainen hakemistorakenne. Yllättävän kätevää. Vähemmän kätevää oli hahmottaa mitä tulokseksi saadaan.
#
# Tässä `image_dataset_from_directory()` on `keras.preprosessing` alla, mutta Tensorflow 2.8 nähtävästi `keras.utils` alla.

# %%
#katsotaan luokkien nimet, että menee varmasti oikein
print(train_dataset.class_names)
# Out:
# ['ants', 'bees']

# %%
#muutama satunnaisesti valittava esimerkkikuva datasta
file_path_1 = ['data/hymenoptera/train/ants/*.jpg']
file_path_2 = ['data/hymenoptera/train/bees/*.jpg']
ant_images = glob.glob(random.choice(file_path_1))
bee_images = glob.glob(random.choice(file_path_2))

#ylärivillä muurahaisia...
ipyplot.plot_images([random.choice(ant_images), random.choice(ant_images), random.choice(ant_images)],
                    img_width=180)
#...ja alarivillä mesipistiäisiä
ipyplot.plot_images([random.choice(bee_images), random.choice(bee_images), random.choice(bee_images)], 
                    img_width=180)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-9XoZfXSS5GradgcYpqHJoR {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-9XoZfXSS5GradgcYpqHJoR {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-9XoZfXSS5GradgcYpqHJoR {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-9XoZfXSS5GradgcYpqHJoR:checked ~ #ipyplot-html-viewer-textarea-9XoZfXSS5GradgcYpqHJoR {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-9XoZfXSS5GradgcYpqHJoR:checked + #ipyplot-html-viewer-label-9XoZfXSS5GradgcYpqHJoR:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-9XoZfXSS5GradgcYpqHJoR">
#         <label id="ipyplot-html-viewer-label-9XoZfXSS5GradgcYpqHJoR" for="ipyplot-html-viewer-toggle-9XoZfXSS5GradgcYpqHJoR">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-9XoZfXSS5GradgcYpqHJoR" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-bbTMmZzf9xizeB3vNKEHSf {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-bbTMmZzf9xizeB3vNKEHSf {
#             width: 180px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf {
#             width: 180px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf img {
#             width: 180px;
#         }
#
#         div.ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-bbTMmZzf9xizeB3vNKEHSf">
#     <div class="ipyplot-placeholder-div-bbTMmZzf9xizeB3vNKEHSf">
#         <div id="ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf-brzwNtNWnThmRMdCmGpHUy" class="ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data\hymenoptera\train\ants\154124431_65460430f2.jpg</h4><img src="data\hymenoptera\train\ants\154124431_65460430f2.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf-brzwNtNWnThmRMdCmGpHUy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bbTMmZzf9xizeB3vNKEHSf">
#         <div id="ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf-TU7Kc5ZYDuaqntZNA7CUYM" class="ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data\hymenoptera\train\ants\20935278_9190345f6b.jpg</h4><img src="data\hymenoptera\train\ants\20935278_9190345f6b.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf-TU7Kc5ZYDuaqntZNA7CUYM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bbTMmZzf9xizeB3vNKEHSf">
#         <div id="ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf-38AJpsjNYRbmtmbyC9X9wZ" class="ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data\hymenoptera\train\ants\207947948_3ab29d7207.jpg</h4><img src="data\hymenoptera\train\ants\207947948_3ab29d7207.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf-38AJpsjNYRbmtmbyC9X9wZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-bbTMmZzf9xizeB3vNKEHSf {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-bbTMmZzf9xizeB3vNKEHSf {
#             width: 180px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf {
#             width: 180px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf img {
#             width: 180px;
#         }
#
#         div.ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-bbTMmZzf9xizeB3vNKEHSf">
#     <div class="ipyplot-placeholder-div-bbTMmZzf9xizeB3vNKEHSf">
#         <div id="ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf-brzwNtNWnThmRMdCmGpHUy" class="ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data\hymenoptera\train\ants\154124431_65460430f2.jpg</h4><img src="data\hymenoptera\train\ants\154124431_65460430f2.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf-brzwNtNWnThmRMdCmGpHUy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bbTMmZzf9xizeB3vNKEHSf">
#         <div id="ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf-TU7Kc5ZYDuaqntZNA7CUYM" class="ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data\hymenoptera\train\ants\20935278_9190345f6b.jpg</h4><img src="data\hymenoptera\train\ants\20935278_9190345f6b.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf-TU7Kc5ZYDuaqntZNA7CUYM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bbTMmZzf9xizeB3vNKEHSf">
#         <div id="ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf-38AJpsjNYRbmtmbyC9X9wZ" class="ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data\hymenoptera\train\ants\207947948_3ab29d7207.jpg</h4><img src="data\hymenoptera\train\ants\207947948_3ab29d7207.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bbTMmZzf9xizeB3vNKEHSf-38AJpsjNYRbmtmbyC9X9wZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#     <style>
#         #ipyplot-html-viewer-toggle-hDAFAupufP2Rs26ixDpEQh {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-hDAFAupufP2Rs26ixDpEQh {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-hDAFAupufP2Rs26ixDpEQh {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-hDAFAupufP2Rs26ixDpEQh:checked ~ #ipyplot-html-viewer-textarea-hDAFAupufP2Rs26ixDpEQh {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-hDAFAupufP2Rs26ixDpEQh:checked + #ipyplot-html-viewer-label-hDAFAupufP2Rs26ixDpEQh:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-hDAFAupufP2Rs26ixDpEQh">
#         <label id="ipyplot-html-viewer-label-hDAFAupufP2Rs26ixDpEQh" for="ipyplot-html-viewer-toggle-hDAFAupufP2Rs26ixDpEQh">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-hDAFAupufP2Rs26ixDpEQh" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-AbNCfPVzbLsicHFBznRDtA {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-AbNCfPVzbLsicHFBznRDtA {
#             width: 180px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA {
#             width: 180px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA img {
#             width: 180px;
#         }
#
#         div.ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-AbNCfPVzbLsicHFBznRDtA">
#     <div class="ipyplot-placeholder-div-AbNCfPVzbLsicHFBznRDtA">
#         <div id="ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA-Z26bNfXejZ8yLNsvqVPLrJ" class="ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data\hymenoptera\train\bees\969455125_58c797ef17.jpg</h4><img src="data\hymenoptera\train\bees\969455125_58c797ef17.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA-Z26bNfXejZ8yLNsvqVPLrJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-AbNCfPVzbLsicHFBznRDtA">
#         <div id="ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA-WxLgn63AhwwJPaJgvBezFn" class="ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data\hymenoptera\train\bees\39747887_42df2855ee.jpg</h4><img src="data\hymenoptera\train\bees\39747887_42df2855ee.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA-WxLgn63AhwwJPaJgvBezFn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-AbNCfPVzbLsicHFBznRDtA">
#         <div id="ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA-3VPQy4pD7v2QkKtUvJdQgo" class="ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data\hymenoptera\train\bees\129236073_0985e91c7d.jpg</h4><img src="data\hymenoptera\train\bees\129236073_0985e91c7d.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA-3VPQy4pD7v2QkKtUvJdQgo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-AbNCfPVzbLsicHFBznRDtA {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-AbNCfPVzbLsicHFBznRDtA {
#             width: 180px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA {
#             width: 180px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA img {
#             width: 180px;
#         }
#
#         div.ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-AbNCfPVzbLsicHFBznRDtA">
#     <div class="ipyplot-placeholder-div-AbNCfPVzbLsicHFBznRDtA">
#         <div id="ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA-Z26bNfXejZ8yLNsvqVPLrJ" class="ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data\hymenoptera\train\bees\969455125_58c797ef17.jpg</h4><img src="data\hymenoptera\train\bees\969455125_58c797ef17.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA-Z26bNfXejZ8yLNsvqVPLrJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-AbNCfPVzbLsicHFBznRDtA">
#         <div id="ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA-WxLgn63AhwwJPaJgvBezFn" class="ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data\hymenoptera\train\bees\39747887_42df2855ee.jpg</h4><img src="data\hymenoptera\train\bees\39747887_42df2855ee.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA-WxLgn63AhwwJPaJgvBezFn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-AbNCfPVzbLsicHFBznRDtA">
#         <div id="ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA-3VPQy4pD7v2QkKtUvJdQgo" class="ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data\hymenoptera\train\bees\129236073_0985e91c7d.jpg</h4><img src="data\hymenoptera\train\bees\129236073_0985e91c7d.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-AbNCfPVzbLsicHFBznRDtA-3VPQy4pD7v2QkKtUvJdQgo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
#Prefetch. Tarkoitus on nopeuttaa koneen toimintaa
train_data = train_dataset.prefetch(buffer_size=32)
test_data = test_dataset.prefetch(buffer_size=32)
train_data
# Out:
# <PrefetchDataset shapes: ((None, 224, 224, 3), (None,)), types: (tf.float32, tf.int32)>

# %% [markdown]
# # oma kommentti
# Tämä on oikeastaan todella vaikea datasetti. Itse kohde on näissä useimmiten pieni osa kuvaa ja harvoin kovin puhtaasti edustettuna. Toisaalta näin se on luonnossakin. Myös ihan luontoharrastajan näkökulmasta pistiäisporukka on ärsyttävän valpasta ja otuksesta saa harvoin lähikuvaa. Kuvia voi tietysti jälkeenpäin croppailla, mutta muuten asian kanssa on elettävä, jos haluaa että työkalusta on käytännössä mitään hyötyä.
#
# Esikäsittelyyn liittyvänä yksityiskohtana train-aineistossa oli mukana yksi verkkosiipinen ja kaksi muurahaista jäljittelevää hämähäkkiä. Kuvat kannatti silmäillä läpi.
#
# Prefetch on käsittääkseni jonkinlaista välimuistittamista. Temppu löytyi, kun koetin löytää keinoja nopeuttaa analysointia.

# %%
#neuroverkon toteutus
#rakennetaan konvoluutioneuroverkko

input_layer = tf.keras.Input(shape=(224, 224, 3))
normalization = tf.keras.layers.experimental.preprocessing.Rescaling(scale=1.0/255)(input_layer)
convolution1 = tf.keras.layers.Conv2D(48, kernel_size=(2, 2), padding='same', strides=1, activation='relu')(normalization)
pooling1 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(convolution1)
convolution2 = tf.keras.layers.Conv2D(18, kernel_size=(2, 2), padding='same', strides=1, activation='relu')(pooling1)
pooling2 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(convolution2)
dropout1 = tf.keras.layers.Dropout(0.2)(pooling2)
flattened = tf.keras.layers.Flatten()(dropout1)
dense1 = tf.keras.layers.Dense(8, activation='relu')(flattened)
output_layer = tf.keras.layers.Dense(1, activation='sigmoid')(dense1) #tulos on binäärisesti ant tai bee

tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

model = tf.keras.Model(inputs=input_layer, outputs=output_layer)

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

fit = model.fit(train_data, batch_size=10, epochs=10, validation_data=test_data)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 16s 2s/step - loss: 0.9457 - accuracy: 0.4298 - val_loss: 0.7942 - val_accuracy: 0.4510
# Epoch 2/10
# 8/8 [==============================] - 16s 2s/step - loss: 0.6696 - accuracy: 0.5909 - val_loss: 0.7116 - val_accuracy: 0.5556
# Epoch 3/10
# 8/8 [==============================] - 16s 2s/step - loss: 0.6429 - accuracy: 0.6777 - val_loss: 0.6794 - val_accuracy: 0.5229
# Epoch 4/10
# 8/8 [==============================] - 17s 2s/step - loss: 0.6165 - accuracy: 0.6901 - val_loss: 0.6899 - val_accuracy: 0.5359
# Epoch 5/10
# 8/8 [==============================] - 19s 2s/step - loss: 0.5666 - accuracy: 0.6777 - val_loss: 0.6853 - val_accuracy: 0.5882
# Epoch 6/10
# 8/8 [==============================] - 16s 2s/step - loss: 0.5423 - accuracy: 0.7479 - val_loss: 0.6655 - val_accuracy: 0.6078
# Epoch 7/10
# 8/8 [==============================] - 15s 2s/step - loss: 0.4744 - accuracy: 0.8058 - val_loss: 0.7705 - val_accuracy: 0.5686
# Epoch 8/10
# 8/8 [==============================] - 16s 2s/step - loss: 0.4360 - accuracy: 0.8017 - val_loss: 0.6666 - val_accuracy: 0.6078
# Epoch 9/10
# 8/8 [==============================] - 16s 2s/step - loss: 0.3982 - accuracy: 0.8430 - val_loss: 0.6815 - val_accuracy: 0.5948
# Epoch 10/10
# 8/8 [==============================] - 16s 2s/step - loss: 0.3582 - accuracy: 0.8595 - val_loss: 0.6988 - val_accuracy: 0.6013

# %% [markdown]
# # oma kommentti
# Neuroverkko on rakennettu yksinkertaisesta input > conv2d > flattened > dense -rakenteesta alkaen, paremman teorian puutteessa pitkälti fiilispohjalta. Eräänlaisena esikäsittelynä `keras.layers.experimental.preprocessing.Rescaling()` skaalaa pikseliarvot. Kurssin tf versiossa 2.3 se on tuossa kirjastossa, uudemmissa suoraan `keras.layer` alla. Yksivärinen data olisi helpompaa ja nopeampaa käsitellä, mutta väri-informaatio on tässä aika olennaista. Useimmat muurahaislajit ovat yksivärisen tummanruskeita tai punaisia, kun mesipistäisissä myös keltaiset sävyt ja jonkinasteinen kirjavuus ovat hyvin tavallisia.
#
# Aloittaessa idea vaikutti hauskalta, mutta verkko näyttää pääsevän vain 50-60 % tarkkuuteen. Olen rehellisesti sanottuna tosi pettynyt tulokseen. Ei tälle nyt oikein mitään mielekästä jatkoakaan saa rakennettua. Vähän lässähti motivaatio nyt.

# %%
#tarkkuuden tarkastelu
loss, accuracy = model.evaluate(test_dataset, verbose=1)
print(f'Loss: {loss}, accuracy: {accuracy}')
# Out:
# 5/5 [==============================] - 2s 329ms/step - loss: 0.6988 - accuracy: 0.6013
# Loss: 0.6987718939781189, accuracy: 0.601307213306427

# %% [markdown]
# # oma kommentti
# Työskentelyn iloa vähensi merkittävästi, se tosiasia, ettei läppärissä tunnu tehot riittävän kovin syviin malleihin. Jatkokehitystä varten pitää odotella että joku kustantaa paremmat resurssit.
#
# Aineisto on kieltämättä vaikea. Kohde on usein pieni osa koko kuvasta ja sekä muurahaiset että mesipistiäiset muistuttavat toisiaan. Tämä ei nyt ollut oikeastaan kovin produktiivista. Työn päälimmäiseksi sisällöksi jäi oma, sinänsä parantunut, ymmärrys siitä, kuinka automaattinen lajintunnistus onnistuu... ja kuinka hankalaa se voikaan olla. Sovellusten käytössä kannattaa siis jatkossakin panostaa kuvan laatuun (kuten tietysti aina muutenkin).
